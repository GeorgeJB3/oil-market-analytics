# %%
dbutils.library.restartPython()

# %%
# import sys

# sys.path.append(
#     '/Workspace/Repos/gjbaldwin94@gmail.com/oil-market-analytics/src'
# )

# %%
from src.transforms.silver.silver_energy_prices import generate_silver_energy_price_table
from src.transforms.silver.silver_index import generate_silver_index_tables

# %%
from pyspark.sql.functions import col, desc, avg, round

# %%
# Make changes to the import to contain all sheets and headers
uk_gdp_df = spark.table("oil_analytics.bronze_uk_gdp")
uk_interest_rate_df = spark.table("oil_analytics.bronze_uk_interest_rate")

# %%
uk_cpi_df = spark.table("oil_analytics.bronze_uk_cpi")
fed_cpi_df = spark.table("oil_analytics.bronze_fed_cpi")
fed_gdp_df = spark.table("oil_analytics.bronze_fed_gdp")
fed_interest_rate_df = spark.table("oil_analytics.bronze_fed_interest_rate")

# %%
fed_unemployment_df = spark.table("oil_analytics.bronze_fed_unemployment")
uk_unemployment_df = spark.table("oil_analytics.bronze_uk_unemployment")

# %%
uk_unemployment_df.display()

# %%
uk_unemployment_df = uk_unemployment_df.filter((col("Economic_Activity") == "Total unemployed - aged 16 and over") & (col("Value_Type") == "Level") & (col("measures").like("Unemployment rates use employment plus%") ))

# %%
uk_unemployment_df = uk_unemployment_df \
    .groupBy("date") \
        .agg(round(avg("value"), 1).alias("unemployment_rate"))


# Sort format of date - currently in 3 month

# %%
uk_unemployment_df.display()

# %%
#fed_unemployment_df.orderBy(desc("date")).display()
